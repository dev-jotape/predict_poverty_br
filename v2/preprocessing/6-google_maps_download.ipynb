# %%
# from sentinelsat import SentinelAPI, read_geojson, geojson_to_wkt
# from datetime import date
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
import requests

# %%
geo_ntl = gpd.read_file('../dataset/shapefiles/br/grid_area_filtered.shp')
geo_ntl
# Out:
#         CD_MUN       NM_MUN SIGLA   AREA_KM2      area   avg_ntl  \
# 0      1100205  Porto Velho    RO  34090.952  0.000081  3.033283
# 1      1100205  Porto Velho    RO  34090.952  0.000081  7.458409
# 2      1100205  Porto Velho    RO  34090.952  0.000081  3.941893
# 3      1100205  Porto Velho    RO  34090.952  0.000081  7.031119
# 4      1100205  Porto Velho    RO  34090.952  0.000081  4.513860
# ...        ...          ...   ...        ...       ...       ...
# 29368  5300108     Brasília    DF   5760.784  0.000081  6.286755
# 29369  5300108     Brasília    DF   5760.784  0.000081  3.028190
# 29370  5300108     Brasília    DF   5760.784  0.000081  5.125547
# 29371  5300108     Brasília    DF   5760.784  0.000081  4.134818
# 29372  5300108     Brasília    DF   5760.784  0.000081  4.138090
#
#                                                 geometry
# 0      POLYGON ((-66.621 -9.775, -66.621 -9.766, -66....
# 1      POLYGON ((-66.621 -9.766, -66.621 -9.757, -66....
# ...

# %%
base_url = "http://maps.googleapis.com/maps/api/staticmap?"
key = "AIzaSyA8EiEJa9LRpNJ3urknuIMfOjxDH_tI0KA"
count = 0

# %%
# Functions to download images -----------------------------------------------

def download_image(lat, lon, filename):
    # file_exists = exists(filename)
    # if not file_exists:
    param_url = "maptype=satellite&center="+ lat + "," + lon + "&zoom=16&size=400x400&style=feature:all|element:labels|visibility:off&format=png&key="
    final_url = base_url + param_url + key
    r = requests.get(final_url)
    if r.status_code == 200:
        with open(filename, 'wb') as img:
            img.write(r.content)
    else:
        print('ERRO TO GET IMAGE ', r.status_code)

# %%
geo_ntl["id"] = geo_ntl.index + 1
geo_ntl['lon'] = geo_ntl.centroid.x  
geo_ntl['lat'] = geo_ntl.centroid.y
geo_ntl['round_ntl'] = round(geo_ntl.avg_ntl * 10**6)
geo_ntl
# Out:
#         CD_MUN       NM_MUN SIGLA   AREA_KM2      area   avg_ntl  \
# 0      1100205  Porto Velho    RO  34090.952  0.000081  3.033283
# 1      1100205  Porto Velho    RO  34090.952  0.000081  7.458409
# 2      1100205  Porto Velho    RO  34090.952  0.000081  3.941893
# 3      1100205  Porto Velho    RO  34090.952  0.000081  7.031119
# 4      1100205  Porto Velho    RO  34090.952  0.000081  4.513860
# ...        ...          ...   ...        ...       ...       ...
# 29368  5300108     Brasília    DF   5760.784  0.000081  6.286755
# 29369  5300108     Brasília    DF   5760.784  0.000081  3.028190
# 29370  5300108     Brasília    DF   5760.784  0.000081  5.125547
# 29371  5300108     Brasília    DF   5760.784  0.000081  4.134818
# 29372  5300108     Brasília    DF   5760.784  0.000081  4.138090
#
#                                                 geometry        lon  \
# 0      POLYGON ((-66.621 -9.775, -66.621 -9.766, -66.... -66.616753
# ...

# %%
image_folder_url = '../dataset/google_images_v2/'
# geo_ntl = geo_ntl[geo_ntl['avg_ntl'] > 50]
for i, row in geo_ntl.iterrows():
    intensity = row['avg_ntl']
    intensity_file = round(intensity * 10**6)
    city_code = row['CD_MUN']
    id = row['id']
    lat = row['lat']
    lon = row['lon']

    filename = image_folder_url + str(city_code) + '_' + str(id) + '_' + str(intensity_file) + '.png'
    download_image(str(lat), str(lon), filename)
    # break
