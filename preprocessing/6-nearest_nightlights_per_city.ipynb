# %%
import pandas as pd

# %%
df = pd.read_csv('../model/coordinates_with_distances.csv')
df
# Out:
#          city_code                city  uf        lat       long  radiance  \
# 0          1101450            Parecis   RO -12.004167 -61.333332  0.226823
# 1          1101450            Parecis   RO -12.004167 -61.329166  0.252866
# 2          1101450            Parecis   RO -12.004167 -61.324999  0.221371
# 3          1101450            Parecis   RO -12.004167 -61.320832  0.203252
# 4          1101450            Parecis   RO -12.004167 -61.316666  0.213139
# ...            ...                 ...  ..        ...        ...       ...
# 1212028    5204250  Cachoeira Dourada   GO -18.612501 -49.741666  0.273667
# 1212029    5204250  Cachoeira Dourada   GO -18.612501 -49.737499  0.284952
# 1212030    5204250  Cachoeira Dourada   GO -18.612501 -49.733332  0.268688
# 1212031    5204250  Cachoeira Dourada   GO -18.612501 -49.729166  0.248612
# 1212032    5204250  Cachoeira Dourada   GO -18.616667 -49.737499  0.266826
#
# ...

# %%
# remove < 0
df = df[df['radiance'] > 0]
df
# Out:
#          city_code                city  uf        lat       long  radiance  \
# 0          1101450            Parecis   RO -12.004167 -61.333332  0.226823
# 1          1101450            Parecis   RO -12.004167 -61.329166  0.252866
# 2          1101450            Parecis   RO -12.004167 -61.324999  0.221371
# 3          1101450            Parecis   RO -12.004167 -61.320832  0.203252
# 4          1101450            Parecis   RO -12.004167 -61.316666  0.213139
# ...            ...                 ...  ..        ...        ...       ...
# 1212028    5204250  Cachoeira Dourada   GO -18.612501 -49.741666  0.273667
# 1212029    5204250  Cachoeira Dourada   GO -18.612501 -49.737499  0.284952
# 1212030    5204250  Cachoeira Dourada   GO -18.612501 -49.733332  0.268688
# 1212031    5204250  Cachoeira Dourada   GO -18.612501 -49.729166  0.248612
# 1212032    5204250  Cachoeira Dourada   GO -18.616667 -49.737499  0.266826
#
# ...

# %%
df['rank'] = df.groupby('city_code')['distance_to_city'].rank()
nearest = df[df['rank'] <= 100]
nearest
# Out:
# C:\Users\Pedro\AppData\Local\Temp\ipykernel_6084\1720358833.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rank'] = df.groupby('city_code')['distance_to_city'].rank()
#          city_code                city  uf        lat       long  radiance  \
# 3186       1101450            Parecis   RO -12.158334 -61.604166  0.235929
# 3187       1101450            Parecis   RO -12.158334 -61.599999  0.252750
# 3188       1101450            Parecis   RO -12.158334 -61.595832  0.253744
# 3189       1101450            Parecis   RO -12.158334 -61.591666  0.231304
# 3303       1101450            Parecis   RO -12.162501 -61.612499  0.235071
# ...            ...                 ...  ..        ...        ...       ...
# ...

# %%
nearest.to_csv('../model/nearest_nightlights_per_city.csv', index=False)
